# %%
# %env SM_FRAMEWORK=tf.keras
# Out:
# env: SM_FRAMEWORK=tf.keras

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import keras
import cv2
import segmentation_models as sm
# Out:
# 2023-09-05 15:10:18.881313: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-09-05 15:10:18.913690: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-09-05 15:10:19.388375: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Segmentation Models: using `tf.keras` framework.

# %%
import mlflow
mlflow.set_tracking_uri("databricks")
mlflow.set_experiment("/Users/danimar301@student.polsl.pl/Extraterrestial-Rock-Segmentation")
# Out:
# <Experiment: artifact_location='dbfs:/databricks/mlflow-tracking/1048085717579938', creation_time=1668775123782, experiment_id='1048085717579938', last_update_time=1673965167011, lifecycle_stage='active', name='/Users/danimar301@student.polsl.pl/Extraterrestial-Rock-Segmentation', tags={'mlflow.experiment.sourceName': '/Users/danimar301@student.polsl.pl/Extraterrestial-Rock-Segmentation',
#  'mlflow.experimentType': 'MLFLOW_EXPERIMENT',
#  'mlflow.ownerEmail': 'danimar301@student.polsl.pl',
#  'mlflow.ownerId': '7796760964070965'}>

# %%
# Prepare paths of input images and target segmentation masks
# RockA is a simple data set with a few rocks
# RockB is more challanging -- according to description on github
input_dir_rockA = "../datasets with noise/rock-a"
target_dir_rockA = "../MarsData/MarsData-main/Data/Rock-A/label/Rock-A mask"

input_dir_rockB = "../datasets with noise/rock-b"
target_dir_rockB = "../MarsData/MarsData-main/Data/Rock-B/label/Rock-B mask"

img_size = (320,320)
# img_size = (336, 336)

rockA_input_img_paths = sorted([
    os.path.join(input_dir_rockA, fname)
    for fname in os.listdir(input_dir_rockA)
    if fname.endswith(".png")
])

#Sorting mask names in target folder
rockA_target_img_paths = sorted([
    os.path.join(target_dir_rockA, fname)
    for fname in os.listdir(target_dir_rockA)
    if fname.endswith(".png") and not fname.startswith(".")
])

rockB_input_img_paths = sorted([
    os.path.join(input_dir_rockB, fname)
    for fname in os.listdir(input_dir_rockB)
    if fname.endswith(".png")
])

#Sorting mask names in target folder
rockB_target_img_paths = sorted([
    os.path.join(target_dir_rockB, fname)
    for fname in os.listdir(target_dir_rockB)
    if fname.endswith(".png") and not fname.startswith(".")
])

print("Number of Rock-A input samples:", len(rockA_input_img_paths))
print("Number of Rock-A target samples:", len(rockA_target_img_paths))

for input_path, target_path in zip(rockA_input_img_paths[:10], rockA_target_img_paths[:10]):
    print(input_path, "|", target_path)
    
print("Number of Rock-B input samples:", len(rockB_input_img_paths))
print("Number of Rock-B target samples:", len(rockB_target_img_paths))

for input_path, target_path in zip(rockB_input_img_paths[:10], rockB_target_img_paths[:10]):
    print(input_path, "|", target_path)
# Out:
# Number of Rock-A input samples: 201
# Number of Rock-A target samples: 201
# ../datasets with noise/rock-a/1516_1516ML0077220050604247E01_DXXX_aug_1.png | ../MarsData/MarsData-main/Data/Rock-A/label/Rock-A mask/1516_1516ML0077220050604247E01_DXXX.png
# ../datasets with noise/rock-a/1516_1516MR0077180000204657E01_DXXX_aug_1.png | ../MarsData/MarsData-main/Data/Rock-A/label/Rock-A mask/1516_1516MR0077180000204657E01_DXXX.png
# ../datasets with noise/rock-a/1518_1518ML0077330000604252E01_DXXX_aug_1.png | ../MarsData/MarsData-main/Data/Rock-A/label/Rock-A mask/1518_1518ML0077330000604252E01_DXXX.png
# ../datasets with noise/rock-a/1518_1518ML0077330050604257E01_DXXX_aug_1.png | ../MarsData/MarsData-main/Data/Rock-A/label/Rock-A mask/1518_1518ML0077330050604257E01_DXXX.png
# ../datasets with noise/rock-a/1518_1518ML0077330060604258E02_DXXX_aug_1.png | ../MarsData/MarsData-main/Data/Rock-A/label/Rock-A mask/1518_1518ML0077330060604258E02_DXXX.png
# ../datasets with noise/rock-a/1518_1518MR0077310000204672E01_DXXX_aug_1.png | ../MarsData/MarsData-main/Data/Rock-A/label/Rock-A mask/1518_1518MR0077310000204672E01_DXXX.png
# ../datasets with noise/rock-a/1521_1521MR0077430000204724E01_DXXX_aug_1.png | ../MarsData/MarsData-main/Data/Rock-A/label/Rock-A mask/1521_1521MR0077430000204724E01_DXXX.png
# ../datasets with noise/rock-a/1521_1521MR0077450010204727E01_DXXX_aug_1.png | ../MarsData/MarsData-main/Data/Rock-A/label/Rock-A mask/1521_1521MR0077450010204727E01_DXXX.png
# ../datasets with noise/rock-a/1521_1521MR0077460010204729E01_DXXX_aug_1.png | ../MarsData/MarsData-main/Data/Rock-A/label/Rock-A mask/1521_1521MR0077460010204729E01_DXXX.png
# ../datasets with noise/rock-a/1521_1521MR0077460020204730E01_DXXX_aug_1.png | ../MarsData/MarsData-main/Data/Rock-A/label/Rock-A mask/1521_1521MR0077460020204730E01_DXXX.png
# Number of Rock-B input samples: 204
# Number of Rock-B target samples: 204
# ../datasets with noise/rock-b/1044_1044MR0045730180204466E01_DXXX_aug_1.png | ../MarsData/MarsData-main/Data/Rock-B/label/Rock-B mask/1044_1044MR0045730180204466E01_DXXX.png
# ../datasets with noise/rock-b/1044_1044MR0045730190204467E01_DXXX_aug_1.png | ../MarsData/MarsData-main/Data/Rock-B/label/Rock-B mask/1044_1044MR0045730190204467E01_DXXX.png
# ../datasets with noise/rock-b/1044_1044MR0045730480204496E01_DXXX_aug_1.png | ../MarsData/MarsData-main/Data/Rock-B/label/Rock-B mask/1044_1044MR0045730480204496E01_DXXX.png
# ../datasets with noise/rock-b/1044_1044MR0045730490204497E01_DXXX_aug_1.png | ../MarsData/MarsData-main/Data/Rock-B/label/Rock-B mask/1044_1044MR0045730490204497E01_DXXX.png
# ../datasets with noise/rock-b/1047_1047ML0046000200306022E01_DXXX_aug_1.png | ../MarsData/MarsData-main/Data/Rock-B/label/Rock-B mask/1047_1047ML0046000200306022E01_DXXX.png
# ../datasets with noise/rock-b/1047_1047ML0046000210306023E01_DXXX_aug_1.png | ../MarsData/MarsData-main/Data/Rock-B/label/Rock-B mask/1047_1047ML0046000210306023E01_DXXX.png
# ../datasets with noise/rock-b/1047_1047ML0046000220306024E01_DXXX_aug_1.png | ../MarsData/MarsData-main/Data/Rock-B/label/Rock-B mask/1047_1047ML0046000220306024E01_DXXX.png
# ../datasets with noise/rock-b/1053_1053ML0046350050306113E01_DXXX_aug_1.png | ../MarsData/MarsData-main/Data/Rock-B/label/Rock-B mask/1053_1053ML0046350050306113E01_DXXX.png
# ../datasets with noise/rock-b/1077_1077MR0047340420600156E01_DXXX_aug_1.png | ../MarsData/MarsData-main/Data/Rock-B/label/Rock-B mask/1077_1077MR0047340420600156E01_DXXX.png
# ../datasets with noise/rock-b/1077_1077MR0047340430600157E01_DXXX_aug_1.png | ../MarsData/MarsData-main/Data/Rock-B/label/Rock-B mask/1077_1077MR0047340430600157E01_DXXX.png

# %%
# auxiliary utility functions
def extract_mask_from_ground(ground_img, lower_color_threshold):
    (R, G, B) = cv2.split(ground_img)
    
    # Values are clipped as it is a binary classification problem
    R_ranged = np.clip(cv2.inRange(R, lower_color_threshold, 255), 0, 1) 
    G_ranged = np.clip(cv2.inRange(G, lower_color_threshold, 255), 0, 1) 
    B_ranged = np.clip(cv2.inRange(B, lower_color_threshold, 255), 0, 1)

    merged = cv2.merge([B_ranged, G_ranged, R_ranged])
    merged = np.expand_dims(merged, 3)
    merged = np.amax(merged, axis=2)
    return merged

# The threshold value determines how many small rocks are visible, higher threshold means less blue rocks
def load_ground(path, color_threshold):
    img_ground = cv2.imread(path)
    img_ground_rgb = cv2.cvtColor(img_ground, cv2.COLOR_BGR2RGB)
    img_ground_rgb = cv2.resize(img_ground_rgb, img_size[::-1])
    return extract_mask_from_ground(img_ground_rgb, color_threshold)

# %%
from IPython.display import Image, display
from tensorflow.keras.preprocessing.image import load_img
import PIL
from PIL import ImageOps

image_index = 2

# Display input image 
print("Input image: ")
display(Image(filename=rockA_input_img_paths[image_index], width = 320, height = 320))

print("Target image: ")
img_ground = load_ground(rockA_target_img_paths[image_index], 1)
display(tf.keras.preprocessing.image.array_to_img(img_ground))

print(img_ground.shape)
print(np.unique(img_ground))
# Out:
# Input image:
# Target image:
# <PIL.Image.Image image mode=L size=320x320>
# (320, 320, 1)
# [0 1]

# %%
from IPython.display import Image, display
from tensorflow.keras.preprocessing.image import load_img
import PIL
from PIL import ImageOps

image_index = 2

# Display input image 
print("Input image: ")
display(Image(filename=rockB_input_img_paths[image_index], width = 320, height = 320))

print("Target image: ")
img_ground = load_ground(rockB_target_img_paths[image_index], 1)
display(tf.keras.preprocessing.image.array_to_img(img_ground))

print(img_ground.shape)
print(np.unique(img_ground))
# Out:
# Input image:
# Target image:
# <PIL.Image.Image image mode=L size=320x320>
# (320, 320, 1)
# [0 1]

# %%
from skimage import color
class MartianRocks(keras.utils.Sequence):
    def __init__(self, batch_size, img_size, input_img_paths, target_img_paths, color_threshold):
        self.batch_size = batch_size
        self.img_size = img_size
        self.input_img_paths = input_img_paths
        self.target_img_paths = target_img_paths
        self.color_threshold = color_threshold
        
    def __len__(self):
        return len(self.target_img_paths) // self.batch_size
    
    def __getitem__(self, idx):
        # Returns tuple (input, target) corresponding to batch idx
        i = idx * self.batch_size
        batch_input_img_paths = self.input_img_paths[i : i + self.batch_size]
        batch_target_img_paths = self.target_img_paths[i : i + self.batch_size]
        
        # 3 Dimensional input images
        x = np.zeros((self.batch_size,) + self.img_size + (3,), dtype="float32")
        for j, path in enumerate(batch_input_img_paths):
            img = load_img(path, target_size = self.img_size)
            x[j] = img
                
        # 1 Dimensional target mask
        y = np.zeros((self.batch_size,) + self.img_size + (1,), dtype="uint8")
        for j, path in enumerate(batch_target_img_paths):
            # load ground imahe
            y[j] = load_ground(path, self.color_threshold)
                
        return x, y
    
class MartianRocksGreyscaled(MartianRocks):
    
    def __getitem__(self, idx):
        # Returns tuple (input, target) corresponding to batch idx
        i = idx * self.batch_size
        batch_input_img_paths = self.input_img_paths[i : i + self.batch_size]
        batch_target_img_paths = self.target_img_paths[i : i + self.batch_size]
        
        # 3 Dimensional input images
        x = np.zeros((self.batch_size,) + self.img_size + (3,), dtype="float32")
        for j, path in enumerate(batch_input_img_paths):
            img = load_img(path, target_size = self.img_size)
            img = color.rgb2gray(img)
            img =  np.repeat(img[..., np.newaxis], 3, -1)
            x[j] = img
                
        # 1 Dimensional target mask
        y = np.zeros((self.batch_size,) + self.img_size + (1,), dtype="uint8")
        for j, path in enumerate(batch_target_img_paths):
            # load ground imahe
            y[j] = load_ground(path, self.color_threshold)
                
        return x, y

# %%
loader = MartianRocks(16, img_size, rockA_input_img_paths[:250], 
            rockA_target_img_paths[:250], color_threshold = 1)

print(type(loader.__getitem__(3)))
print(np.unique(loader.__getitem__(1)[1][1]))
print(type(loader.__getitem__(1)[1][3][0][0][0]))
batch = loader.__getitem__(2)
display(tf.keras.preprocessing.image.array_to_img(batch[0][1]))
display(tf.keras.preprocessing.image.array_to_img(batch[1][1]))

loaderGreyscaled = MartianRocksGreyscaled(
            16, img_size, rockA_input_img_paths[:250], 
            rockA_target_img_paths[:250], color_threshold = 1)

print(type(loaderGreyscaled.__getitem__(3)))
print(np.unique(loaderGreyscaled.__getitem__(1)[1][1]))
print(type(loaderGreyscaled.__getitem__(1)[1][3][0][0][0]))
batch = loaderGreyscaled.__getitem__(2)
display(tf.keras.preprocessing.image.array_to_img(batch[0][1]))
display(tf.keras.preprocessing.image.array_to_img(batch[1][1]))
# Out:
# <class 'tuple'>
# [0 1]
# <class 'numpy.uint8'>
# <PIL.Image.Image image mode=RGB size=320x320>
# <PIL.Image.Image image mode=L size=320x320>
# <class 'tuple'>
# [0 1]
# <class 'numpy.uint8'>
# <PIL.Image.Image image mode=RGB size=320x320>
# <PIL.Image.Image image mode=L size=320x320>

# %%
rockA_generator = MartianRocks(16, img_size, rockA_input_img_paths, 
            rockA_target_img_paths, color_threshold = 1)

rockB_generator = MartianRocks(16, img_size, rockB_input_img_paths, 
            rockB_target_img_paths, color_threshold = 1)

# %%
from segmentation_models.losses  import bce_jaccard_loss
from segmentation_models.metrics import IOUScore

run_id = 0

# This line downloads models from mlflow artifacts
temp_dir = mlflow.artifacts.download_artifacts(
    'dbfs:/databricks/mlflow-tracking/1048085717579938/ebbdc78331674d99b2aaf8b5a279e5a9/artifacts/model')
print(temp_dir)
model = keras.models.load_model(temp_dir + '/data/model', compile=False)
model.summary()
# Out:
# Downloading artifacts:   0%|          | 0/11 [00:00<?, ?it/s]
# 2023/09/05 15:27:00 INFO mlflow.store.artifact.artifact_repo: The progress bar can be disabled by setting the environment variable MLFLOW_ENABLE_ARTIFACTS_PROGRESS_BAR to false
# /tmp/tmp_o535e8y/model
# WARNING:tensorflow:Unable to restore custom metric. Please ensure that the layer implements `get_config` and `from_config` when saving. In addition, please use the `custom_objects` arg when calling `load_model()`.
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 320, 320, 3)]        0         []
#
#  Conv1_pad (ZeroPadding2D)   (None, 321, 321, 3)          0         ['input_1[0][0]']
#
#  Conv1 (Conv2D)              (None, 160, 160, 32)         864       ['Conv1_pad[0][0]']
#
#  bn_Conv1 (BatchNormalizati  (None, 160, 160, 32)         128       ['Conv1[0][0]']
#  on)
#
#  Conv1_relu (ReLU)           (None, 160, 160, 32)         0         ['bn_Conv1[0][0]']
#
#  expanded_conv_depthwise (D  (None, 160, 160, 32)         288       ['Conv1_relu[0][0]']
#  epthwiseConv2D)
#
#  expanded_conv_depthwise_BN  (None, 160, 160, 32)         128       ['expanded_conv_depthwise[0][0
#   (BatchNormalization)                                              ]']
#
#  expanded_conv_depthwise_re  (None, 160, 160, 32)         0         ['expanded_conv_depthwise_BN[0
#  lu (ReLU)                                                          ][0]']
#
#  expanded_conv_project (Con  (None, 160, 160, 16)         512       ['expanded_conv_depthwise_relu
#  v2D)                                                               [0][0]']
#
#  expanded_conv_project_BN (  (None, 160, 160, 16)         64        ['expanded_conv_project[0][0]'
#  BatchNormalization)                                                ]
#
#  block_1_expand (Conv2D)     (None, 160, 160, 96)         1536      ['expanded_conv_project_BN[0][
#                                                                     0]']
#
#  block_1_expand_BN (BatchNo  (None, 160, 160, 96)         384       ['block_1_expand[0][0]']
#  rmalization)
#
#  block_1_expand_relu (ReLU)  (None, 160, 160, 96)         0         ['block_1_expand_BN[0][0]']
#
#  block_1_pad (ZeroPadding2D  (None, 161, 161, 96)         0         ['block_1_expand_relu[0][0]']
#  )
#
#  block_1_depthwise (Depthwi  (None, 80, 80, 96)           864       ['block_1_pad[0][0]']
#  seConv2D)
#
#  block_1_depthwise_BN (Batc  (None, 80, 80, 96)           384       ['block_1_depthwise[0][0]']
#  hNormalization)
#
#  block_1_depthwise_relu (Re  (None, 80, 80, 96)           0         ['block_1_depthwise_BN[0][0]']
#  LU)
#
#  block_1_project (Conv2D)    (None, 80, 80, 24)           2304      ['block_1_depthwise_relu[0][0]
#                                                                     ']
#
#  block_1_project_BN (BatchN  (None, 80, 80, 24)           96        ['block_1_project[0][0]']
#  ormalization)
#
#  block_2_expand (Conv2D)     (None, 80, 80, 144)          3456      ['block_1_project_BN[0][0]']
#
#  block_2_expand_BN (BatchNo  (None, 80, 80, 144)          576       ['block_2_expand[0][0]']
#  rmalization)
#
#  block_2_expand_relu (ReLU)  (None, 80, 80, 144)          0         ['block_2_expand_BN[0][0]']
#
#  block_2_depthwise (Depthwi  (None, 80, 80, 144)          1296      ['block_2_expand_relu[0][0]']
#  seConv2D)
#
#  block_2_depthwise_BN (Batc  (None, 80, 80, 144)          576       ['block_2_depthwise[0][0]']
#  hNormalization)
#
#  block_2_depthwise_relu (Re  (None, 80, 80, 144)          0         ['block_2_depthwise_BN[0][0]']
#  LU)
#
#  block_2_project (Conv2D)    (None, 80, 80, 24)           3456      ['block_2_depthwise_relu[0][0]
#                                                                     ']
#
#  block_2_project_BN (BatchN  (None, 80, 80, 24)           96        ['block_2_project[0][0]']
#  ormalization)
#
#  block_2_add (Add)           (None, 80, 80, 24)           0         ['block_1_project_BN[0][0]',
#                                                                      'block_2_project_BN[0][0]']
#
#  block_3_expand (Conv2D)     (None, 80, 80, 144)          3456      ['block_2_add[0][0]']
#
#  block_3_expand_BN (BatchNo  (None, 80, 80, 144)          576       ['block_3_expand[0][0]']
#  rmalization)
#
#  block_3_expand_relu (ReLU)  (None, 80, 80, 144)          0         ['block_3_expand_BN[0][0]']
#
#  block_3_pad (ZeroPadding2D  (None, 81, 81, 144)          0         ['block_3_expand_relu[0][0]']
#  )
#
#  block_3_depthwise (Depthwi  (None, 40, 40, 144)          1296      ['block_3_pad[0][0]']
#  seConv2D)
#
#  block_3_depthwise_BN (Batc  (None, 40, 40, 144)          576       ['block_3_depthwise[0][0]']
#  hNormalization)
#
#  block_3_depthwise_relu (Re  (None, 40, 40, 144)          0         ['block_3_depthwise_BN[0][0]']
#  LU)
#
#  block_3_project (Conv2D)    (None, 40, 40, 32)           4608      ['block_3_depthwise_relu[0][0]
#                                                                     ']
#
#  block_3_project_BN (BatchN  (None, 40, 40, 32)           128       ['block_3_project[0][0]']
#  ormalization)
#
#  block_4_expand (Conv2D)     (None, 40, 40, 192)          6144      ['block_3_project_BN[0][0]']
#
#  block_4_expand_BN (BatchNo  (None, 40, 40, 192)          768       ['block_4_expand[0][0]']
#  rmalization)
#
#  block_4_expand_relu (ReLU)  (None, 40, 40, 192)          0         ['block_4_expand_BN[0][0]']
#
#  block_4_depthwise (Depthwi  (None, 40, 40, 192)          1728      ['block_4_expand_relu[0][0]']
#  seConv2D)
#
#  block_4_depthwise_BN (Batc  (None, 40, 40, 192)          768       ['block_4_depthwise[0][0]']
#  hNormalization)
#
#  block_4_depthwise_relu (Re  (None, 40, 40, 192)          0         ['block_4_depthwise_BN[0][0]']
#  LU)
#
#  block_4_project (Conv2D)    (None, 40, 40, 32)           6144      ['block_4_depthwise_relu[0][0]
#                                                                     ']
#
#  block_4_project_BN (BatchN  (None, 40, 40, 32)           128       ['block_4_project[0][0]']
#  ormalization)
#
#  block_4_add (Add)           (None, 40, 40, 32)           0         ['block_3_project_BN[0][0]',
#                                                                      'block_4_project_BN[0][0]']
#
#  block_5_expand (Conv2D)     (None, 40, 40, 192)          6144      ['block_4_add[0][0]']
#
#  block_5_expand_BN (BatchNo  (None, 40, 40, 192)          768       ['block_5_expand[0][0]']
#  rmalization)
#
#  block_5_expand_relu (ReLU)  (None, 40, 40, 192)          0         ['block_5_expand_BN[0][0]']
#
#  block_5_depthwise (Depthwi  (None, 40, 40, 192)          1728      ['block_5_expand_relu[0][0]']
#  seConv2D)
#
#  block_5_depthwise_BN (Batc  (None, 40, 40, 192)          768       ['block_5_depthwise[0][0]']
#  hNormalization)
#
#  block_5_depthwise_relu (Re  (None, 40, 40, 192)          0         ['block_5_depthwise_BN[0][0]']
#  LU)
#
#  block_5_project (Conv2D)    (None, 40, 40, 32)           6144      ['block_5_depthwise_relu[0][0]
#                                                                     ']
#
#  block_5_project_BN (BatchN  (None, 40, 40, 32)           128       ['block_5_project[0][0]']
#  ormalization)
#
#  block_5_add (Add)           (None, 40, 40, 32)           0         ['block_4_add[0][0]',
#                                                                      'block_5_project_BN[0][0]']
#
#  block_6_expand (Conv2D)     (None, 40, 40, 192)          6144      ['block_5_add[0][0]']
#
#  block_6_expand_BN (BatchNo  (None, 40, 40, 192)          768       ['block_6_expand[0][0]']
#  rmalization)
#
#  block_6_expand_relu (ReLU)  (None, 40, 40, 192)          0         ['block_6_expand_BN[0][0]']
#
#  block_6_pad (ZeroPadding2D  (None, 41, 41, 192)          0         ['block_6_expand_relu[0][0]']
#  )
#
#  block_6_depthwise (Depthwi  (None, 20, 20, 192)          1728      ['block_6_pad[0][0]']
#  seConv2D)
#
#  block_6_depthwise_BN (Batc  (None, 20, 20, 192)          768       ['block_6_depthwise[0][0]']
#  hNormalization)
#
#  block_6_depthwise_relu (Re  (None, 20, 20, 192)          0         ['block_6_depthwise_BN[0][0]']
#  LU)
#
#  block_6_project (Conv2D)    (None, 20, 20, 64)           12288     ['block_6_depthwise_relu[0][0]
#                                                                     ']
#
#  block_6_project_BN (BatchN  (None, 20, 20, 64)           256       ['block_6_project[0][0]']
#  ormalization)
#
#  block_7_expand (Conv2D)     (None, 20, 20, 384)          24576     ['block_6_project_BN[0][0]']
#
#  block_7_expand_BN (BatchNo  (None, 20, 20, 384)          1536      ['block_7_expand[0][0]']
#  rmalization)
#
#  block_7_expand_relu (ReLU)  (None, 20, 20, 384)          0         ['block_7_expand_BN[0][0]']
#
#  block_7_depthwise (Depthwi  (None, 20, 20, 384)          3456      ['block_7_expand_relu[0][0]']
#  seConv2D)
#
#  block_7_depthwise_BN (Batc  (None, 20, 20, 384)          1536      ['block_7_depthwise[0][0]']
#  hNormalization)
#
#  block_7_depthwise_relu (Re  (None, 20, 20, 384)          0         ['block_7_depthwise_BN[0][0]']
#  LU)
#
#  block_7_project (Conv2D)    (None, 20, 20, 64)           24576     ['block_7_depthwise_relu[0][0]
#                                                                     ']
#
#  block_7_project_BN (BatchN  (None, 20, 20, 64)           256       ['block_7_project[0][0]']
#  ormalization)
#
#  block_7_add (Add)           (None, 20, 20, 64)           0         ['block_6_project_BN[0][0]',
#                                                                      'block_7_project_BN[0][0]']
#
#  block_8_expand (Conv2D)     (None, 20, 20, 384)          24576     ['block_7_add[0][0]']
#
#  block_8_expand_BN (BatchNo  (None, 20, 20, 384)          1536      ['block_8_expand[0][0]']
#  rmalization)
#
#  block_8_expand_relu (ReLU)  (None, 20, 20, 384)          0         ['block_8_expand_BN[0][0]']
#
#  block_8_depthwise (Depthwi  (None, 20, 20, 384)          3456      ['block_8_expand_relu[0][0]']
#  seConv2D)
#
#  block_8_depthwise_BN (Batc  (None, 20, 20, 384)          1536      ['block_8_depthwise[0][0]']
#  hNormalization)
#
#  block_8_depthwise_relu (Re  (None, 20, 20, 384)          0         ['block_8_depthwise_BN[0][0]']
#  LU)
#
#  block_8_project (Conv2D)    (None, 20, 20, 64)           24576     ['block_8_depthwise_relu[0][0]
#                                                                     ']
#
#  block_8_project_BN (BatchN  (None, 20, 20, 64)           256       ['block_8_project[0][0]']
#  ormalization)
#
#  block_8_add (Add)           (None, 20, 20, 64)           0         ['block_7_add[0][0]',
#                                                                      'block_8_project_BN[0][0]']
#
#  block_9_expand (Conv2D)     (None, 20, 20, 384)          24576     ['block_8_add[0][0]']
#
#  block_9_expand_BN (BatchNo  (None, 20, 20, 384)          1536      ['block_9_expand[0][0]']
#  rmalization)
#
#  block_9_expand_relu (ReLU)  (None, 20, 20, 384)          0         ['block_9_expand_BN[0][0]']
#
#  block_9_depthwise (Depthwi  (None, 20, 20, 384)          3456      ['block_9_expand_relu[0][0]']
#  seConv2D)
#
#  block_9_depthwise_BN (Batc  (None, 20, 20, 384)          1536      ['block_9_depthwise[0][0]']
#  hNormalization)
#
#  block_9_depthwise_relu (Re  (None, 20, 20, 384)          0         ['block_9_depthwise_BN[0][0]']
#  LU)
#
#  block_9_project (Conv2D)    (None, 20, 20, 64)           24576     ['block_9_depthwise_relu[0][0]
#                                                                     ']
#
#  block_9_project_BN (BatchN  (None, 20, 20, 64)           256       ['block_9_project[0][0]']
#  ormalization)
#
#  block_9_add (Add)           (None, 20, 20, 64)           0         ['block_8_add[0][0]',
#                                                                      'block_9_project_BN[0][0]']
#
#  block_10_expand (Conv2D)    (None, 20, 20, 384)          24576     ['block_9_add[0][0]']
#
#  block_10_expand_BN (BatchN  (None, 20, 20, 384)          1536      ['block_10_expand[0][0]']
#  ormalization)
#
#  block_10_expand_relu (ReLU  (None, 20, 20, 384)          0         ['block_10_expand_BN[0][0]']
#  )
#
#  block_10_depthwise (Depthw  (None, 20, 20, 384)          3456      ['block_10_expand_relu[0][0]']
#  iseConv2D)
#
#  block_10_depthwise_BN (Bat  (None, 20, 20, 384)          1536      ['block_10_depthwise[0][0]']
#  chNormalization)
#
#  block_10_depthwise_relu (R  (None, 20, 20, 384)          0         ['block_10_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_10_project (Conv2D)   (None, 20, 20, 96)           36864     ['block_10_depthwise_relu[0][0
#                                                                     ]']
#
#  block_10_project_BN (Batch  (None, 20, 20, 96)           384       ['block_10_project[0][0]']
#  Normalization)
#
#  block_11_expand (Conv2D)    (None, 20, 20, 576)          55296     ['block_10_project_BN[0][0]']
#
#  block_11_expand_BN (BatchN  (None, 20, 20, 576)          2304      ['block_11_expand[0][0]']
#  ormalization)
#
#  block_11_expand_relu (ReLU  (None, 20, 20, 576)          0         ['block_11_expand_BN[0][0]']
#  )
#
#  block_11_depthwise (Depthw  (None, 20, 20, 576)          5184      ['block_11_expand_relu[0][0]']
#  iseConv2D)
#
#  block_11_depthwise_BN (Bat  (None, 20, 20, 576)          2304      ['block_11_depthwise[0][0]']
#  chNormalization)
#
#  block_11_depthwise_relu (R  (None, 20, 20, 576)          0         ['block_11_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_11_project (Conv2D)   (None, 20, 20, 96)           55296     ['block_11_depthwise_relu[0][0
#                                                                     ]']
#
#  block_11_project_BN (Batch  (None, 20, 20, 96)           384       ['block_11_project[0][0]']
#  Normalization)
#
#  block_11_add (Add)          (None, 20, 20, 96)           0         ['block_10_project_BN[0][0]',
#                                                                      'block_11_project_BN[0][0]']
#
#  block_12_expand (Conv2D)    (None, 20, 20, 576)          55296     ['block_11_add[0][0]']
#
#  block_12_expand_BN (BatchN  (None, 20, 20, 576)          2304      ['block_12_expand[0][0]']
#  ormalization)
#
#  block_12_expand_relu (ReLU  (None, 20, 20, 576)          0         ['block_12_expand_BN[0][0]']
#  )
#
#  block_12_depthwise (Depthw  (None, 20, 20, 576)          5184      ['block_12_expand_relu[0][0]']
#  iseConv2D)
#
#  block_12_depthwise_BN (Bat  (None, 20, 20, 576)          2304      ['block_12_depthwise[0][0]']
#  chNormalization)
#
#  block_12_depthwise_relu (R  (None, 20, 20, 576)          0         ['block_12_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_12_project (Conv2D)   (None, 20, 20, 96)           55296     ['block_12_depthwise_relu[0][0
#                                                                     ]']
#
#  block_12_project_BN (Batch  (None, 20, 20, 96)           384       ['block_12_project[0][0]']
#  Normalization)
#
#  block_12_add (Add)          (None, 20, 20, 96)           0         ['block_11_add[0][0]',
#                                                                      'block_12_project_BN[0][0]']
#
#  block_13_expand (Conv2D)    (None, 20, 20, 576)          55296     ['block_12_add[0][0]']
#
#  block_13_expand_BN (BatchN  (None, 20, 20, 576)          2304      ['block_13_expand[0][0]']
#  ormalization)
#
#  block_13_expand_relu (ReLU  (None, 20, 20, 576)          0         ['block_13_expand_BN[0][0]']
#  )
#
#  block_13_pad (ZeroPadding2  (None, 21, 21, 576)          0         ['block_13_expand_relu[0][0]']
#  D)
#
#  block_13_depthwise (Depthw  (None, 10, 10, 576)          5184      ['block_13_pad[0][0]']
#  iseConv2D)
#
#  block_13_depthwise_BN (Bat  (None, 10, 10, 576)          2304      ['block_13_depthwise[0][0]']
#  chNormalization)
#
#  block_13_depthwise_relu (R  (None, 10, 10, 576)          0         ['block_13_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_13_project (Conv2D)   (None, 10, 10, 160)          92160     ['block_13_depthwise_relu[0][0
#                                                                     ]']
#
#  block_13_project_BN (Batch  (None, 10, 10, 160)          640       ['block_13_project[0][0]']
#  Normalization)
#
#  block_14_expand (Conv2D)    (None, 10, 10, 960)          153600    ['block_13_project_BN[0][0]']
#
#  block_14_expand_BN (BatchN  (None, 10, 10, 960)          3840      ['block_14_expand[0][0]']
#  ormalization)
#
#  block_14_expand_relu (ReLU  (None, 10, 10, 960)          0         ['block_14_expand_BN[0][0]']
#  )
#
#  block_14_depthwise (Depthw  (None, 10, 10, 960)          8640      ['block_14_expand_relu[0][0]']
#  iseConv2D)
#
#  block_14_depthwise_BN (Bat  (None, 10, 10, 960)          3840      ['block_14_depthwise[0][0]']
#  chNormalization)
#
#  block_14_depthwise_relu (R  (None, 10, 10, 960)          0         ['block_14_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_14_project (Conv2D)   (None, 10, 10, 160)          153600    ['block_14_depthwise_relu[0][0
#                                                                     ]']
#
#  block_14_project_BN (Batch  (None, 10, 10, 160)          640       ['block_14_project[0][0]']
#  Normalization)
#
#  block_14_add (Add)          (None, 10, 10, 160)          0         ['block_13_project_BN[0][0]',
#                                                                      'block_14_project_BN[0][0]']
#
#  block_15_expand (Conv2D)    (None, 10, 10, 960)          153600    ['block_14_add[0][0]']
#
#  block_15_expand_BN (BatchN  (None, 10, 10, 960)          3840      ['block_15_expand[0][0]']
#  ormalization)
#
#  block_15_expand_relu (ReLU  (None, 10, 10, 960)          0         ['block_15_expand_BN[0][0]']
#  )
#
#  block_15_depthwise (Depthw  (None, 10, 10, 960)          8640      ['block_15_expand_relu[0][0]']
#  iseConv2D)
#
#  block_15_depthwise_BN (Bat  (None, 10, 10, 960)          3840      ['block_15_depthwise[0][0]']
#  chNormalization)
#
#  block_15_depthwise_relu (R  (None, 10, 10, 960)          0         ['block_15_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_15_project (Conv2D)   (None, 10, 10, 160)          153600    ['block_15_depthwise_relu[0][0
#                                                                     ]']
#
#  block_15_project_BN (Batch  (None, 10, 10, 160)          640       ['block_15_project[0][0]']
#  Normalization)
#
#  block_15_add (Add)          (None, 10, 10, 160)          0         ['block_14_add[0][0]',
#                                                                      'block_15_project_BN[0][0]']
#
#  block_16_expand (Conv2D)    (None, 10, 10, 960)          153600    ['block_15_add[0][0]']
#
#  block_16_expand_BN (BatchN  (None, 10, 10, 960)          3840      ['block_16_expand[0][0]']
#  ormalization)
#
#  block_16_expand_relu (ReLU  (None, 10, 10, 960)          0         ['block_16_expand_BN[0][0]']
#  )
#
#  block_16_depthwise (Depthw  (None, 10, 10, 960)          8640      ['block_16_expand_relu[0][0]']
#  iseConv2D)
#
#  block_16_depthwise_BN (Bat  (None, 10, 10, 960)          3840      ['block_16_depthwise[0][0]']
#  chNormalization)
#
#  block_16_depthwise_relu (R  (None, 10, 10, 960)          0         ['block_16_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_16_project (Conv2D)   (None, 10, 10, 320)          307200    ['block_16_depthwise_relu[0][0
#                                                                     ]']
#
#  block_16_project_BN (Batch  (None, 10, 10, 320)          1280      ['block_16_project[0][0]']
#  Normalization)
#
#  Conv_1 (Conv2D)             (None, 10, 10, 1280)         409600    ['block_16_project_BN[0][0]']
#
#  Conv_1_bn (BatchNormalizat  (None, 10, 10, 1280)         5120      ['Conv_1[0][0]']
#  ion)
#
#  out_relu (ReLU)             (None, 10, 10, 1280)         0         ['Conv_1_bn[0][0]']
#
#  decoder_stage0a_conv (Conv  (None, 10, 10, 320)          409600    ['out_relu[0][0]']
#  2D)
#
#  decoder_stage0a_bn (BatchN  (None, 10, 10, 320)          1280      ['decoder_stage0a_conv[0][0]']
#  ormalization)
#
#  decoder_stage0a_relu (Acti  (None, 10, 10, 320)          0         ['decoder_stage0a_bn[0][0]']
#  vation)
#
#  decoder_stage0_upsampling   (None, 20, 20, 320)          0         ['decoder_stage0a_relu[0][0]']
#  (UpSampling2D)
#
#  decoder_stage0b_conv (Conv  (None, 20, 20, 320)          921600    ['decoder_stage0_upsampling[0]
#  2D)                                                                [0]']
#
#  decoder_stage0b_bn (BatchN  (None, 20, 20, 320)          1280      ['decoder_stage0b_conv[0][0]']
#  ormalization)
#
#  decoder_stage0b_relu (Acti  (None, 20, 20, 320)          0         ['decoder_stage0b_bn[0][0]']
#  vation)
#
#  decoder_stage0c_conv (Conv  (None, 20, 20, 576)          184320    ['decoder_stage0b_relu[0][0]']
#  2D)
#
#  decoder_stage0c_bn (BatchN  (None, 20, 20, 576)          2304      ['decoder_stage0c_conv[0][0]']
#  ormalization)
#
#  decoder_stage0c_relu (Acti  (None, 20, 20, 576)          0         ['decoder_stage0c_bn[0][0]']
#  vation)
#
#  decoder_stage0_add (Add)    (None, 20, 20, 576)          0         ['decoder_stage0c_relu[0][0]',
#                                                                      'block_13_expand_relu[0][0]']
#
#  decoder_stage1a_conv (Conv  (None, 20, 20, 144)          82944     ['decoder_stage0_add[0][0]']
#  2D)
#
#  decoder_stage1a_bn (BatchN  (None, 20, 20, 144)          576       ['decoder_stage1a_conv[0][0]']
#  ormalization)
#
#  decoder_stage1a_relu (Acti  (None, 20, 20, 144)          0         ['decoder_stage1a_bn[0][0]']
#  vation)
#
#  decoder_stage1_upsampling   (None, 40, 40, 144)          0         ['decoder_stage1a_relu[0][0]']
#  (UpSampling2D)
#
#  decoder_stage1b_conv (Conv  (None, 40, 40, 144)          186624    ['decoder_stage1_upsampling[0]
#  2D)                                                                [0]']
#
#  decoder_stage1b_bn (BatchN  (None, 40, 40, 144)          576       ['decoder_stage1b_conv[0][0]']
#  ormalization)
#
#  decoder_stage1b_relu (Acti  (None, 40, 40, 144)          0         ['decoder_stage1b_bn[0][0]']
#  vation)
#
#  decoder_stage1c_conv (Conv  (None, 40, 40, 192)          27648     ['decoder_stage1b_relu[0][0]']
#  2D)
#
#  decoder_stage1c_bn (BatchN  (None, 40, 40, 192)          768       ['decoder_stage1c_conv[0][0]']
#  ormalization)
#
#  decoder_stage1c_relu (Acti  (None, 40, 40, 192)          0         ['decoder_stage1c_bn[0][0]']
#  vation)
#
#  decoder_stage1_add (Add)    (None, 40, 40, 192)          0         ['decoder_stage1c_relu[0][0]',
#                                                                      'block_6_expand_relu[0][0]']
#
#  decoder_stage2a_conv (Conv  (None, 40, 40, 48)           9216      ['decoder_stage1_add[0][0]']
#  2D)
#
#  decoder_stage2a_bn (BatchN  (None, 40, 40, 48)           192       ['decoder_stage2a_conv[0][0]']
#  ormalization)
#
#  decoder_stage2a_relu (Acti  (None, 40, 40, 48)           0         ['decoder_stage2a_bn[0][0]']
#  vation)
#
#  decoder_stage2_upsampling   (None, 80, 80, 48)           0         ['decoder_stage2a_relu[0][0]']
#  (UpSampling2D)
#
#  decoder_stage2b_conv (Conv  (None, 80, 80, 48)           20736     ['decoder_stage2_upsampling[0]
#  2D)                                                                [0]']
#
#  decoder_stage2b_bn (BatchN  (None, 80, 80, 48)           192       ['decoder_stage2b_conv[0][0]']
#  ormalization)
#
#  decoder_stage2b_relu (Acti  (None, 80, 80, 48)           0         ['decoder_stage2b_bn[0][0]']
#  vation)
#
#  decoder_stage2c_conv (Conv  (None, 80, 80, 144)          6912      ['decoder_stage2b_relu[0][0]']
#  2D)
#
#  decoder_stage2c_bn (BatchN  (None, 80, 80, 144)          576       ['decoder_stage2c_conv[0][0]']
#  ormalization)
#
#  decoder_stage2c_relu (Acti  (None, 80, 80, 144)          0         ['decoder_stage2c_bn[0][0]']
#  vation)
#
#  decoder_stage2_add (Add)    (None, 80, 80, 144)          0         ['decoder_stage2c_relu[0][0]',
#                                                                      'block_3_expand_relu[0][0]']
#
#  decoder_stage3a_conv (Conv  (None, 80, 80, 36)           5184      ['decoder_stage2_add[0][0]']
#  2D)
#
#  decoder_stage3a_bn (BatchN  (None, 80, 80, 36)           144       ['decoder_stage3a_conv[0][0]']
#  ormalization)
#
#  decoder_stage3a_relu (Acti  (None, 80, 80, 36)           0         ['decoder_stage3a_bn[0][0]']
#  vation)
#
#  decoder_stage3_upsampling   (None, 160, 160, 36)         0         ['decoder_stage3a_relu[0][0]']
#  (UpSampling2D)
#
#  decoder_stage3b_conv (Conv  (None, 160, 160, 36)         11664     ['decoder_stage3_upsampling[0]
#  2D)                                                                [0]']
#
#  decoder_stage3b_bn (BatchN  (None, 160, 160, 36)         144       ['decoder_stage3b_conv[0][0]']
#  ormalization)
#
#  decoder_stage3b_relu (Acti  (None, 160, 160, 36)         0         ['decoder_stage3b_bn[0][0]']
#  vation)
#
#  decoder_stage3c_conv (Conv  (None, 160, 160, 96)         3456      ['decoder_stage3b_relu[0][0]']
#  2D)
#
#  decoder_stage3c_bn (BatchN  (None, 160, 160, 96)         384       ['decoder_stage3c_conv[0][0]']
#  ormalization)
#
#  decoder_stage3c_relu (Acti  (None, 160, 160, 96)         0         ['decoder_stage3c_bn[0][0]']
#  vation)
#
#  decoder_stage3_add (Add)    (None, 160, 160, 96)         0         ['decoder_stage3c_relu[0][0]',
#                                                                      'block_1_expand_relu[0][0]']
#
#  decoder_stage4a_conv (Conv  (None, 160, 160, 24)         2304      ['decoder_stage3_add[0][0]']
#  2D)
#
#  decoder_stage4a_bn (BatchN  (None, 160, 160, 24)         96        ['decoder_stage4a_conv[0][0]']
#  ormalization)
#
#  decoder_stage4a_relu (Acti  (None, 160, 160, 24)         0         ['decoder_stage4a_bn[0][0]']
#  vation)
#
#  decoder_stage4_upsampling   (None, 320, 320, 24)         0         ['decoder_stage4a_relu[0][0]']
#  (UpSampling2D)
#
#  decoder_stage4b_conv (Conv  (None, 320, 320, 24)         5184      ['decoder_stage4_upsampling[0]
#  2D)                                                                [0]']
#
#  decoder_stage4b_bn (BatchN  (None, 320, 320, 24)         96        ['decoder_stage4b_conv[0][0]']
#  ormalization)
#
#  decoder_stage4b_relu (Acti  (None, 320, 320, 24)         0         ['decoder_stage4b_bn[0][0]']
#  vation)
#
#  decoder_stage4c_conv (Conv  (None, 320, 320, 16)         384       ['decoder_stage4b_relu[0][0]']
#  2D)
#
#  decoder_stage4c_bn (BatchN  (None, 320, 320, 16)         64        ['decoder_stage4c_conv[0][0]']
#  ormalization)
#
#  decoder_stage4c_relu (Acti  (None, 320, 320, 16)         0         ['decoder_stage4c_bn[0][0]']
#  vation)
#
#  conv2d (Conv2D)             (None, 320, 320, 4)          580       ['decoder_stage4c_relu[0][0]']
#
#  sigmoid (Activation)        (None, 320, 320, 4)          0         ['conv2d[0][0]']
#
# ==================================================================================================
# Total params: 4145012 (15.81 MB)
# Trainable params: 4106564 (15.67 MB)
# Non-trainable params: 38448 (150.19 KB)
# __________________________________________________________________________________________________

# %%
# tf.keras.utils.plot_model(model, show_shapes=True)
import visualkeras
from tensorflow.python.keras.layers import Dense, Conv2D, Flatten, Dropout, MaxPooling2D, ZeroPadding2D
from PIL import ImageFont

font = ImageFont.truetype('/usr/share/fonts/truetype/roboto-slab/RobotoSlab-Regular.ttf', 500, encoding="unic")  # using comic sans is strictly prohibited!
# visualkeras.layered_view(model, type_ignore=[ZeroPadding2D, Dropout, Flatten])
visualkeras.layered_view(model, scale_xy=1.5, scale_z=1, max_z=1, legend=True, draw_volume=True, type_ignore=[ZeroPadding2D, Dropout, Flatten], spacing=2)
# visualkeras.layered_view(model, scale_xy=3, legend=True)
tf.keras.utils.plot_model(model, to_file="unet_seresnet.png", show_shapes=True)

# %%
from  mlflow.tracking import MlflowClient
client = MlflowClient()

converter = tf.lite.TFLiteConverter.from_saved_model(temp_dir + '/data/model') # path to the SavedModel directory
converter.optimizations = [tf.lite.Optimize.DEFAULT]

# with mlflow.start_run(run_name="LinkNet with MobileNetV2, compressed") as run:
tflite_model = converter.convert()

# run_id = run.info.run_id


# Save the model.
# with open('linknet_mobilenet_compressed.tflite', 'wb') as f:
#   f.write(tflite_model)

# client.log_artifact(run_id, 'linknet_mobilenetv2_compressed.tflite')

interpreter = tf.lite.Interpreter(model_content=tflite_model)
interpreter.allocate_tensors()
# Out:
# 2023-09-05 15:27:54.529237: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:364] Ignored output_format.
# 2023-09-05 15:27:54.529259: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:367] Ignored drop_control_dependency.
# 2023-09-05 15:27:54.529410: I tensorflow/cc/saved_model/reader.cc:45] Reading SavedModel from: /tmp/tmp_o535e8y/model/data/model
# 2023-09-05 15:27:54.545833: I tensorflow/cc/saved_model/reader.cc:91] Reading meta graph with tags { serve }
# 2023-09-05 15:27:54.545855: I tensorflow/cc/saved_model/reader.cc:132] Reading SavedModel debug info (if present) from: /tmp/tmp_o535e8y/model/data/model
# 2023-09-05 15:27:54.604755: I tensorflow/cc/saved_model/loader.cc:231] Restoring SavedModel bundle.
# 2023-09-05 15:27:55.273234: I tensorflow/cc/saved_model/loader.cc:215] Running initialization op on SavedModel bundle at path: /tmp/tmp_o535e8y/model/data/model
# 2023-09-05 15:27:55.422768: I tensorflow/cc/saved_model/loader.cc:314] SavedModel load for tags { serve }; Status: success: OK. Took 893358 microseconds.

# %%
from tqdm import tqdm
def compressed_predict(interpreter, input_paths):
    input_index = interpreter.get_input_details()[0]["index"]
    output_index = interpreter.get_output_details()[0]["index"]
    # Run predictions on ever y image in the "test" dataset.
    predictions = []
    for i, test_image_path in tqdm(enumerate(input_paths)):
        # Pre-processing: add batch dimension and convert to float32 to match with
        # the model's input data format.
        test_image = load_img(test_image_path, target_size = img_size)
        # print(type(test_image))
        # test_image = test_image.astype(np.float32)
        test_image = np.expand_dims(test_image, axis=0).astype(np.float32)
        # print(test_image.shape)
        interpreter.set_tensor(input_index, test_image)

        # Run inference.
        interpreter.invoke()

        # Post-processing: remove batch dimension and find the digit with highest
        # probability.
        pred = interpreter.get_tensor(output_index)
        pred = pred.squeeze(axis=0)
        predictions.append(pred)


    return predictions

rockA_preds_compressed = compressed_predict(interpreter, rockA_input_img_paths)
rockB_preds_compressed = compressed_predict(interpreter, rockB_input_img_paths)
# Out:
# 201it [00:29,  6.79it/s]
# 204it [00:30,  6.78it/s]

# %%
# Generate predictions for rockA set
rockA_preds = model.predict(rockA_generator)

# Generate predictions for greyscaled rockA set
# rockA_greyscaled_preds = model.predict(rockA_grayscaled_generator)

# Generate predictions for rockB set
rockB_preds = model.predict(rockB_generator)

# Generate predictions for greyscaled rockB set
# rockB_greyscaled_preds = model.predict(rockB_grayscaled_generator)
# Out:
# 12/12 [==============================] - 3s 99ms/step
# 12/12 [==============================] - 2s 124ms/step

# %%
from skimage import color
# Display results for validation image with index i

def get_mask(i, preds):
    #Quick utilization to display a model's prediction

    mask = np.argmax(preds[i], axis=2)
    mask = np.expand_dims(mask, axis=-1)
    mask = mask - 1 
    mask = np.clip(mask, 0, 1)
    # img = PIL.ImageOps.autocontrast(tf.keras.preprocessing.image.array_to_img(mask))
    return mask

def show_results(index, input_paths, target_paths, predictions):
    # Load input image
    # print(input_paths[index])
    # print(target_paths[index])
    original = cv2.imread(input_paths[index])
    display(tf.keras.preprocessing.image.array_to_img(original))
    original = cv2.resize(original, img_size)

    #Load ground-truth target mask
    target = load_ground(target_paths[index], 1)

    target_img = tf.keras.preprocessing.image.array_to_img(target)

    # Display mask predicted by model
    pred_mask = get_mask(index, predictions)

    pred_mask_img = PIL.ImageOps.autocontrast(tf.keras.preprocessing.image.array_to_img(pred_mask))

    # Applay segmentation mask onto real image
    final_predicted = color.label2rgb(np.asarray(pred_mask_img), original, bg_label=0)
    final_target = color.label2rgb(np.asarray(target_img), original, bg_label=0)

    # Stack segmentation masks on real images
    final = np.hstack((final_target, final_predicted))

    # Stack only masks
    pred_mask = np.hstack((target, pred_mask))
    display(PIL.ImageOps.autocontrast(tf.keras.preprocessing.image.array_to_img(pred_mask))) 

    display(tf.keras.preprocessing.image.array_to_img(final))
    
def show_results_with_compressed(index, input_paths, target_paths, predictions, predictions_compressed):
    # Load input image
    # print(input_paths[index])
    # print(target_paths[index])
    original = cv2.imread(input_paths[index])
    display(tf.keras.preprocessing.image.array_to_img(original))
    original = cv2.resize(original, img_size)

      #Load ground-truth target mask
    target = load_ground(target_paths[index], 1)

    target_img = tf.keras.preprocessing.image.array_to_img(target)

      # display(tf.keras.preprocessing.image.array_to_img(target))


      # Display mask predicted by model
    pred_mask = get_mask(index, predictions)
    pred_mask_compressed = get_mask(index, predictions_compressed)

    pred_mask_img = PIL.ImageOps.autocontrast(tf.keras.preprocessing.image.array_to_img(pred_mask))
    pred_mask_cprsd_img = PIL.ImageOps.autocontrast(tf.keras.preprocessing.image.array_to_img(pred_mask_compressed))

      # Applay segmentation mask onto real image
    final_predicted = color.label2rgb(np.asarray(pred_mask_img), original, bg_label=0, colors = ['red', 'green', 'blue'])
    final_prediction_cmprsd = color.label2rgb(np.asarray(pred_mask_cprsd_img), original, bg_label=0, colors = ['red', 'green', 'blue'] )
    final_target = color.label2rgb(np.asarray(target_img), original, bg_label=0, colors = ['red', 'green', 'blue'])


    print('Target: ')
    display(tf.keras.preprocessing.image.array_to_img(final_target))

    print('Prediction: ')
    display(tf.keras.preprocessing.image.array_to_img(final_predicted))

    print('Compressed prediction: ')
    display(tf.keras.preprocessing.image.array_to_img(final_prediction_cmprsd))

# %%
i = 9

show_results(i, rockA_input_img_paths, rockA_target_img_paths, rockA_preds)
# Out:
# <PIL.Image.Image image mode=RGB size=320x320>
# <PIL.Image.Image image mode=L size=640x320>
# <PIL.Image.Image image mode=RGB size=640x320>

# %%
# Utility function for evaluating models performance with any given metric
import keras.backend as K

# Calculate dice coefficent for one input array
def dice_coef(y_true, y_pred):
    y_true_f = y_true.flatten()
    y_pred_f = y_pred.flatten()
    intersection = np.sum(y_true_f * y_pred_f)
    smooth = 0.0001
    return (2. * intersection + smooth) / (np.sum(y_true_f) + np.sum(y_pred_f) + smooth)

# Calculate average dice loss for every label
def dice_coef_multilabel(y_true, y_pred, numLabels):
    dice = [0, 0]
    result = 0
    average = 0
    for index in range(numLabels):
        result = dice_coef(y_true[:,:,index], y_pred[:,:,index]) # @Todo: Zbierać dice score dla każdej klasy
        # print("Dice score for class {}: {}".format(index, result))
        dice[index] += result
        average += result
    return (dice, average/numLabels) # taking average

#@todo: make function for evaluating dice loss
def calculate_dice_loss(preds, target_paths, color_threshold=1):
    result = [0,0]
    average = []
    for i, mask in enumerate(preds):
        mask = np.argmax(mask, axis=2)
        mask = np.expand_dims(mask, axis=-1)
        mask = mask - 1
        mask = np.clip(mask, 0, 1)
        target = cv2.imread(target_paths[i])
        target = cv2.cvtColor(target, cv2.COLOR_BGR2RGB)

        target = cv2.resize(target, img_size[::-1])
        target = extract_mask_from_ground(target, color_threshold)

      #One hot encoding so the Dice coefficent works
        mask = tf.one_hot(mask, 2)
        mask = np.squeeze(mask, axis=2)
        target = tf.one_hot(target, 2)
        target = np.squeeze(target, axis=2)
#         print(mask.shape)
#         print(target.shape)
        dice_coef_tuple = dice_coef_multilabel(target, mask, 2)
        average.append(dice_coef_tuple[1])
        for i, value in enumerate(dice_coef_tuple[0]):
            result[i] += value

    for i, value in enumerate(result):
        print("Dice score for class {}: {}".format(i, value/len(preds)))
    return average

# Calculate metrics for all model predictions, returns a list 
def evaluate_model(preds, target_paths_here, metric, color_threshold=1):
    result = []
    metric.reset_states()
    for i, mask in enumerate(preds):
        mask = np.argmax(mask, axis=2)
        mask = np.expand_dims(mask, axis=-1)
        mask = mask - 1
        mask = np.clip(mask, 0, 1)
#         print(np.unique(mask))
        target = cv2.imread(target_paths_here[i])
        target = cv2.cvtColor(target, cv2.COLOR_BGR2RGB)

        target = cv2.resize(target, img_size[::-1])
        target = extract_mask_from_ground(target, color_threshold)

        metric.update_state(target, mask)
        result.append(metric.result().numpy())
    return result

# %%
def double_metrics_calculation(preds, preds_compressed, target, color_threshold=1):
  # Define metrics
    meanIoU = tf.keras.metrics.MeanIoU(num_classes=2)
    accuracy_metric = tf.keras.metrics.Accuracy()
    rmse_metric = tf.keras.metrics.RootMeanSquaredError()

    metrics = []
    metrics_comporessed = []

    # Calculate metrics for test set
    dice = calculate_dice_loss(preds,  target, color_threshold)
    iou = evaluate_model(preds,  target, meanIoU, color_threshold)
    accuracy =  evaluate_model(preds,  target, accuracy_metric, color_threshold)
    rmse = evaluate_model(preds,  target, rmse_metric, color_threshold)

    metrics = [accuracy, dice, iou, rmse]

    # Calculate metrics for test set
    dice_compressed = calculate_dice_loss(preds_compressed,  target, color_threshold)
    iou_compressed = evaluate_model(preds_compressed,  target, meanIoU, color_threshold)
    accuracy_compressed =  evaluate_model(preds_compressed,  target, accuracy_metric, color_threshold)
    rmse_compressed = evaluate_model(preds_compressed,  target, rmse_metric, color_threshold)

    metrics_compressed = [accuracy_compressed, dice_compressed, iou_compressed, rmse_compressed]

    return (metrics, metrics_compressed)

# %%
i = 10
show_results_with_compressed(i, rockA_input_img_paths, rockA_target_img_paths, rockA_preds, rockA_preds_compressed)
(metrics, metrics_compressed) = double_metrics_calculation(rockA_preds, rockA_preds_compressed, rockA_target_img_paths, 1)

print('MPA: ', metrics[0][i])
print('MPA compressed: ', metrics_compressed[0][i])

print('Dice: ', metrics[1][i])
print('Dice compressed: ', metrics_compressed[1][i])
print('IoU: ', metrics[2][i])
print('IoU compressed: ', metrics_compressed[2][i])
print('Rmse: ', metrics[3][i])
print('Rmse compressed: ', metrics_compressed[3][i])
# Out:
# <PIL.Image.Image image mode=RGB size=320x320>
# Target:
# <PIL.Image.Image image mode=RGB size=320x320>
# Prediction:
# <PIL.Image.Image image mode=RGB size=320x320>
# Compressed prediction:
# <PIL.Image.Image image mode=RGB size=320x320>
# Dice score for class 0: 0.7126867452985891
# Dice score for class 1: 0.42147535235925754
# Dice score for class 0: 0.7206066585200648
# Dice score for class 1: 0.4190884766562199
# MPA:  0.5777592
# MPA compressed:  0.57763404
# Dice:  0.7023744853319636
# Dice compressed:  0.7040721526203011
# IoU:  0.40297228
# IoU compressed:  0.40289915
# Rmse:  0.64980054
# Rmse compressed:  0.64989686

# %%
i = 28
show_results_with_compressed(i, rockB_input_img_paths, rockB_target_img_paths, rockB_preds, rockB_preds_compressed)
(metrics, metrics_compressed) = double_metrics_calculation(rockB_preds, rockB_preds_compressed, rockB_target_img_paths, 1)

print('MPA: ', metrics[0][i])
print('MPA compressed: ', metrics_compressed[0][i])

print('Dice: ', metrics[1][i])
print('Dice compressed: ', metrics_compressed[1][i])
print('IoU: ', metrics[2][i])
print('IoU compressed: ', metrics_compressed[2][i])
print('Rmse: ', metrics[3][i])
print('Rmse compressed: ', metrics_compressed[3][i])
# Out:
# <PIL.Image.Image image mode=RGB size=320x320>
# Target:
# <PIL.Image.Image image mode=RGB size=320x320>
# Prediction:
# <PIL.Image.Image image mode=RGB size=320x320>
# Compressed prediction:
# <PIL.Image.Image image mode=RGB size=320x320>
# Dice score for class 0: 0.6176245956539312
# Dice score for class 1: 0.40435314463486466
# Dice score for class 0: 0.6323897443929357
# Dice score for class 1: 0.39876468780565744
# MPA:  0.72441
# MPA compressed:  0.72523504
# Dice:  0.46898024905685626
# Dice compressed:  0.47146269356332315
# IoU:  0.43757686
# IoU compressed:  0.43918133
# Rmse:  0.52496666
# Rmse compressed:  0.52418023

# %%
def eval_preds(preds, img_paths, metric_name="", color_threshold = 1):
    # Define metrics
    meanIoU = tf.keras.metrics.MeanIoU(num_classes=2)
    accuracy = tf.keras.metrics.Accuracy()
    rmse = tf.keras.metrics.RootMeanSquaredError()

    # Calculate metrics for validation set
    dice_loss = np.mean(calculate_dice_loss(preds, img_paths, color_threshold))
    iou = np.mean(evaluate_model(preds, img_paths, meanIoU, color_threshold))
    accuracy =  np.mean(evaluate_model(preds, img_paths, accuracy, color_threshold))
    rmse = np.mean(evaluate_model(preds, img_paths, rmse, color_threshold))

    metrics = [dice_loss, iou, accuracy, rmse]
    
    # Display metrics
    print("Dice score on {} set: {}".format(metric_name, dice_loss))
    print("Mean IoU on {} set: {}".format(metric_name, iou))
    print("Accuracy on {} set: {}".format(metric_name, accuracy))
    print("RMSE on {} set: {}".format(metric_name,rmse))
    print()

    return metrics

# %%
eval_preds(rockA_preds, rockA_target_img_paths, 'rockA')

# eval_preds(rockA_greyscaled_preds, rockA_target_img_paths, 'greyscaled rockA')

eval_preds(rockB_preds, rockB_target_img_paths, 'rockB')

# eval_preds(rockB_greyscaled_preds, rockB_target_img_paths, 'greyscaled rockB')
# Out:
# Dice score for class 0: 0.7126868780902086
# Dice score for class 1: 0.4214756836719891
# Dice score on rockA set: 0.5670812808810988
# Mean IoU on rockA set: 0.4877159595489502
# Accuracy on rockA set: 0.6750087738037109
# RMSE on rockA set: 0.5678931474685669
#
# Dice score for class 0: 0.6176246666720356
# Dice score for class 1: 0.4043531521877794
# Dice score on rockB set: 0.5109889094299075
# Mean IoU on rockB set: 0.45417356491088867
# Accuracy on rockB set: 0.6690980792045593
# RMSE on rockB set: 0.5744878649711609
# [0.5109889094299075, 0.45417356, 0.6690981, 0.57448786]

# %%
def get_all_metrics_as_df(preds, img_paths, color_threshold):
    meanIoU = tf.keras.metrics.MeanIoU(num_classes=2)
    accuracy = tf.keras.metrics.Accuracy()
    rmse = tf.keras.metrics.RootMeanSquaredError()

    dice_loss = calculate_dice_loss(preds, img_paths, color_threshold)
    iou = evaluate_model(preds, img_paths, meanIoU, color_threshold)
    accuracy =  evaluate_model(preds, img_paths, accuracy, color_threshold)
    rmse = evaluate_model(preds, img_paths, rmse, 1)
    
    metrics = [dice_loss, iou, accuracy, rmse]
    metrics = np.array(metrics)
    # metrics = metrics
    # print(metrics.shape)
    return pd.DataFrame(metrics.T, columns=['dice', 'iou', 'mpa', 'rmse'])

model_name = "linknet_mobilenetv2"
df = get_all_metrics_as_df(rockA_preds, rockA_target_img_paths, 1)
df.to_csv("{}_rock-A.csv".format(model_name))

df = get_all_metrics_as_df(rockB_preds, rockB_target_img_paths, 1)
df.to_csv("{}_rock-B.csv".format(model_name))

df = get_all_metrics_as_df(rockA_preds_compressed, rockA_target_img_paths, 1)
df.to_csv("{}_rock-A_compressed.csv".format(model_name))

df = get_all_metrics_as_df(rockB_preds_compressed, rockB_target_img_paths, 1)
df.to_csv("{}_rock-B_compressed.csv".format(model_name))
# Out:
# Dice score for class 0: 0.870849211475468
# Dice score for class 1: 0.5876092824268625
# Dice score for class 0: 0.8683647434764201
# Dice score for class 1: 0.6344088309305843
# Dice score for class 0: 0.8724873273995506
# Dice score for class 1: 0.5820428538790998
# Dice score for class 0: 0.8719700727939278
# Dice score for class 1: 0.6210645257123335

# %% [markdown]
# Todo: fix greyscaled generator
